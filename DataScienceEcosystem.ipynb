# %% [markdown]
# <a href="https://colab.research.google.com/github/rodraxphysics/IBM_Data_Science/blob/main/DataScienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Autor

# %% [markdown]
# Rodrigo Sandoval Brito

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this notebook, Data  Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# *   Python
# *   R
# *   Scala

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
#
#
# *   Pandas
# *   Numpy
# *   PySpark
# *   PyTorch

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | Data Science Tools |
# | ------------------ |
# | Jupyter Notebook   |
# | RStudio            |
# | Visual Studio Code |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data  Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
#
# *   Understand Databases
# *   Introduction to R Studio
# *   Introdution to Github
# * Introduction to Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Author

# %% [markdown]
# Rodrigo Sandoval Brito
